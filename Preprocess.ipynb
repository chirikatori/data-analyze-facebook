# %%
import numpy as np
import pandas as pd
import os
from dotenv import load_dotenv
load_dotenv()
from datetime import datetime
import ast

# %% [markdown]
# ## Read data from CSV

# %%
raw_df = pd.read_csv("Data/raw/playstation1.csv")
raw_df.tail()
# Out:
#                post_id                                               text  \
# 666  10161430145771803  Round 1 - Fight!\n\nA Street Fighter 6 demo la...
# 667  10161429315211803  Unleash your inner beast as the Druid in Diabl...
# 668  10161429575366803  Great news: Firewalk Studios is joining the Pl...
# 669  10161429455771803  Turn the tides in Crash Team Rumble with power...
# 670    257258567130564  The EU Tekken 7 Fight Nights Invitational is l...
#
#                                              post_text  \
# 666  Round 1 - Fight!\n\nA Street Fighter 6 demo la...
# 667  Unleash your inner beast as the Druid in Diabl...
# 668  Great news: Firewalk Studios is joining the Pl...
# 669  Turn the tides in Crash Team Rumble with power...
# 670  The EU Tekken 7 Fight Nights Invitational is l...
#
#                                            shared_text original_text  \
# 666                                                NaN           NaN
# 667                                                NaN           NaN
# 668  BLOG.PLAYSTATION.COM\nWelcoming Firewalk Studi...           NaN
# 669                                                NaN           NaN
# 670                                                NaN           NaN
#
#                     time   timestamp image  \
# 666  2023-04-20 22:40:15  1682030415   NaN
# 667  2023-04-20 17:35:00  1682012100   NaN
# 668  2023-04-20 17:12:52  1682010772   NaN
# 669  2023-04-20 16:00:56  1682006456   NaN
# 670  2023-04-20 15:46:42  1682005602   NaN
#
#                                       image_lowquality images  ...  \
# 666  https://scontent-sin6-2.xx.fbcdn.net/v/t15.525...     []  ...
# 667  https://scontent-sin6-2.xx.fbcdn.net/v/t15.525...     []  ...
# 668  https://external-sin6-2.xx.fbcdn.net/emg1/v/t1...     []  ...
# 669  https://scontent-sin6-4.xx.fbcdn.net/v/t15.525...     []  ...
# 670  https://scontent-sin6-4.xx.fbcdn.net/v/t15.525...     []  ...
#
#                                              w3_fb_url  \
# 666  https://www.facebook.com/playstation/posts/101...
# 667  https://www.facebook.com/playstation/posts/101...
# 668  https://www.facebook.com/playstation/posts/101...
# 669  https://www.facebook.com/playstation/posts/101...
# 670  https://www.facebook.com/playstation/posts/257...
#
#                                              reactions reaction_count  \
# 666  {'like': 829, 'love': 155, 'haha': 8, 'wow': 8...           1008
# 667  {'like': 755, 'love': 120, 'haha': 5, 'wow': 8...            897
# 668  {'like': 3047, 'love': 554, 'haha': 77, 'wow':...           3728
# 669  {'like': 16039, 'love': 8209, 'haha': 26, 'wow...          40275
# 670  {'like': 199, 'love': 33, 'haha': 2, 'wow': 4,...            243
#
#                                                   with      page_id  \
# 666                                                NaN  14104316802
# 667                                                NaN  14104316802
# 668                                                NaN  14104316802
# 669                                                NaN  14104316802
# 670  [{'name': 'Tekken 7', 'link': '/gaming/tekken7...  14104316802
#
#                                                sharers image_id image_ids  \
# 666  <generator object PostExtractor.extract_sharer...      NaN        []
# 667  <generator object PostExtractor.extract_sharer...      NaN        []
# 668  <generator object PostExtractor.extract_sharer...      NaN        []
# 669  <generator object PostExtractor.extract_sharer...      NaN        []
# 670  <generator object PostExtractor.extract_sharer...      NaN        []
#
#     was_live                fetched_time
# 666    False  2023-11-29 15:03:32.149452
# 667    False  2023-11-29 15:03:41.978630
# 668    False  2023-11-29 15:03:51.941445
# 669    False  2023-11-29 15:04:06.605362
# 670    False  2023-11-29 15:04:16.222872
#
# [5 rows x 51 columns]

# %%
len(raw_df)
# Out:
# 671

# %%
raw_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 671 entries, 0 to 670
# Data columns (total 51 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   post_id                        671 non-null    object
#  1   text                           638 non-null    object
#  2   post_text                      638 non-null    object
#  3   shared_text                    81 non-null     object
#  4   original_text                  9 non-null      object
#  5   time                           671 non-null    object
#  6   timestamp                      671 non-null    object
#  7   image                          168 non-null    object
#  8   image_lowquality               670 non-null    object
#  9   images                         664 non-null    object
#  10  images_description             664 non-null    object
#  11  images_lowquality              671 non-null    object
#  12  images_lowquality_description  671 non-null    object
#  13  video                          429 non-null    object
#  14  video_duration_seconds         8 non-null      object
#  15  video_height                   8 non-null      object
#  16  video_id                       429 non-null    object
#  17  video_quality                  8 non-null      object
#  18  video_size_MB                  8 non-null      object
#  19  video_thumbnail                429 non-null    object
#  20  video_watches                  8 non-null      object
#  21  video_width                    8 non-null      object
#  22  likes                          671 non-null    object
#  23  comments                       671 non-null    object
#  24  shares                         671 non-null    object
#  25  post_url                       671 non-null    object
#  26  link                           527 non-null    object
#  27  links                          671 non-null    object
#  28  user_id                        671 non-null    object
#  29  username                       671 non-null    object
#  30  user_url                       671 non-null    object
#  31  is_live                        671 non-null    object
#  32  factcheck                      8 non-null      object
#  33  shared_post_id                 9 non-null      object
#  34  shared_time                    9 non-null      object
#  35  shared_user_id                 9 non-null      object
#  36  shared_username                9 non-null      object
#  37  shared_post_url                9 non-null      object
#  38  available                      671 non-null    object
#  39  comments_full                  671 non-null    object
#  40  reactors                       671 non-null    object
#  41  w3_fb_url                      671 non-null    object
#  42  reactions                      671 non-null    object
#  43  reaction_count                 671 non-null    object
#  44  with                           22 non-null     object
#  45  page_id                        671 non-null    object
#  46  sharers                        671 non-null    object
#  47  image_id                       135 non-null    object
#  48  image_ids                      671 non-null    object
#  49  was_live                       671 non-null    object
#  50  fetched_time                   671 non-null    object
# dtypes: object(51)
# memory usage: 267.5+ KB

# %%
raw_df["comments_full"]
# Out:
# 0      <generator object PostExtractor.extract_commen...
# 1      <generator object PostExtractor.extract_commen...
# 2      <generator object PostExtractor.extract_commen...
# 3      <generator object PostExtractor.extract_commen...
# 4      <generator object PostExtractor.extract_commen...
#                              ...
# 666    <generator object PostExtractor.extract_commen...
# 667    <generator object PostExtractor.extract_commen...
# 668    <generator object PostExtractor.extract_commen...
# 669    <generator object PostExtractor.extract_commen...
# 670    <generator object PostExtractor.extract_commen...
# Name: comments_full, Length: 671, dtype: object

# %% [markdown]
# ## Data preprocessing

# %%
data = raw_df.dropna(axis="columns", thresh=100)
data = raw_df.dropna(subset="w3_fb_url")

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 671 entries, 0 to 670
# Data columns (total 36 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   post_id                        671 non-null    object
#  1   text                           638 non-null    object
#  2   post_text                      638 non-null    object
#  3   time                           671 non-null    object
#  4   timestamp                      671 non-null    object
#  5   image                          168 non-null    object
#  6   image_lowquality               670 non-null    object
#  7   images                         664 non-null    object
#  8   images_description             664 non-null    object
#  9   images_lowquality              671 non-null    object
#  10  images_lowquality_description  671 non-null    object
#  11  video                          429 non-null    object
#  12  video_id                       429 non-null    object
#  13  video_thumbnail                429 non-null    object
#  14  likes                          671 non-null    object
#  15  comments                       671 non-null    object
#  16  shares                         671 non-null    object
#  17  post_url                       671 non-null    object
#  18  link                           527 non-null    object
#  19  links                          671 non-null    object
#  20  user_id                        671 non-null    object
#  21  username                       671 non-null    object
#  22  user_url                       671 non-null    object
#  23  is_live                        671 non-null    object
#  24  available                      671 non-null    object
#  25  comments_full                  671 non-null    object
#  26  reactors                       671 non-null    object
#  27  w3_fb_url                      671 non-null    object
#  28  reactions                      671 non-null    object
#  29  reaction_count                 671 non-null    object
#  30  page_id                        671 non-null    object
#  31  sharers                        671 non-null    object
#  32  image_id                       135 non-null    object
#  33  image_ids                      671 non-null    object
#  34  was_live                       671 non-null    object
#  35  fetched_time                   671 non-null    object
# dtypes: object(36)
# memory usage: 188.8+ KB

# %% [markdown]
# ### Drop columns that is not necessory

# %%
data = data.drop_duplicates(subset="post_id")
data = data.drop(columns=["was_live", "fetched_time", 
                           "timestamp", "image", "images", 
                           "timestamp", "image", "image_lowquality",
                          "images","images_description", 
                          "images_lowquality_description",
                          "is_live", "w3_fb_url", "user_id", "username", "user_url",
                          "available", "image_id", "image_ids", "post_url"
                          ])


data.head()
# Out:
#            post_id                                               text  \
# 0  730016209160819                                                NaN
# 1  729723005856806  PlayStation Plus Premium members can spend two...
# 2  728763929286047  Share of the Week dives into the rogues galler...
# 3  729647439197696  Time to talk turkey.\n\nDig in to Black Friday...
# 4  728960592599714  Which PlayStation Shape are you?\n\nプレイステーション ...
#
#                                            post_text                 time  \
# 0                                                NaN  2023-11-25 09:03:46
# 1  PlayStation Plus Premium members can spend two...  2023-11-24 18:34:27
# 2  Share of the Week dives into the rogues galler...  2023-11-24 17:01:25
# 3  Time to talk turkey.\n\nDig in to Black Friday...  2023-11-24 15:59:28
# 4                   Which PlayStation Shape are you?  2023-11-23 09:10:01
#
#                                    images_lowquality  \
# 0  ['https://scontent-sin6-2.xx.fbcdn.net/v/t39.3...
# 1  ['https://scontent-sin6-2.xx.fbcdn.net/v/t39.3...
# 2  ['https://scontent-sin6-2.xx.fbcdn.net/v/t39.3...
# 3  ['https://scontent-sin6-1.xx.fbcdn.net/v/t39.3...
# 4  ['https://scontent-sin6-2.xx.fbcdn.net/v/t15.5...
#
#                                                video         video_id  \
# 0                                                NaN              NaN
# 1                                                NaN              NaN
# 2                                                NaN              NaN
# 3                                                NaN              NaN
# 4  https://scontent-sin6-4.xx.fbcdn.net/v/t42.179...  355486430302074
#
#                                      video_thumbnail likes comments shares  \
# 0                                                NaN   331       27      5
# 1                                                NaN  1672      645    100
# 2                                                NaN  1301       55    140
# 3                                                NaN   577      152     21
# 4  https://scontent-sin6-2.xx.fbcdn.net/v/t15.525...   232       46     27
#
#                                                 link  \
# 0                                                NaN
# 1  http://play.st/46vrSBk?fbclid=IwAR3GOZbEQUh3Cm...
# 2  http://play.st/3MWJW0b?fbclid=IwAR3RXfHAOiHHj0...
# 3  https://play.st/49PebQt?fbclid=IwAR2FKWq8ipoNM...
# 4  https://play.st/49FJWvj?fbclid=IwAR0LHhqDX-250...
#
#                                                links  \
# 0  [{'link': '/story.php?story_fbid=8697658714805...
# 1  [{'link': 'https://lm.facebook.com/l.php?u=htt...
# 2  [{'link': '/hashtag/spiderman2ps5?refid=17&_ft...
# 3  [{'link': 'https://lm.facebook.com/l.php?u=htt...
# 4  [{'link': '/story.php?story_fbid=pfbid02u9iyTX...
#
#                                        comments_full  \
# 0  <generator object PostExtractor.extract_commen...
# 1  <generator object PostExtractor.extract_commen...
# 2  <generator object PostExtractor.extract_commen...
# 3  <generator object PostExtractor.extract_commen...
# 4  <generator object PostExtractor.extract_commen...
#
#                                             reactors  \
# 0  <generator object PostExtractor.extract_reacto...
# 1  <generator object PostExtractor.extract_reacto...
# 2  <generator object PostExtractor.extract_reacto...
# 3  <generator object PostExtractor.extract_reacto...
# 4  <generator object PostExtractor.extract_reacto...
#
#                                            reactions reaction_count  \
# 0  {'like': 331, 'love': 80, 'haha': 8, 'wow': 1,...            426
# 1  {'like': 1672, 'love': 286, 'haha': 184, 'wow'...           2198
# 2  {'like': 1301, 'love': 502, 'haha': 7, 'wow': ...           1831
# 3  {'like': 577, 'love': 50, 'haha': 89, 'wow': 1...            724
# 4  {'like': 232, 'love': 43, 'haha': 8, 'wow': 6,...            293
#
#        page_id                                            sharers
# 0  14104316802  <generator object PostExtractor.extract_sharer...
# 1  14104316802  <generator object PostExtractor.extract_sharer...
# 2  14104316802  <generator object PostExtractor.extract_sharer...
# 3  14104316802  <generator object PostExtractor.extract_sharer...
# 4  14104316802  <generator object PostExtractor.extract_sharer...

# %% [markdown]
# ### Create column "has_video" and drop all video columns

# %%
has_vid = []
for vid in data["video"]:
    if vid is not np.nan:
        has_vid.append(True)
    else:
        has_vid.append(False)
data["has_vid"] = pd.DataFrame(has_vid)
data.head()
# Out:
#            post_id                                               text  \
# 0  730016209160819                                                NaN
# 1  729723005856806  PlayStation Plus Premium members can spend two...
# 2  728763929286047  Share of the Week dives into the rogues galler...
# 3  729647439197696  Time to talk turkey.\n\nDig in to Black Friday...
# 4  728960592599714  Which PlayStation Shape are you?\n\nプレイステーション ...
#
#                                            post_text                 time  \
# 0                                                NaN  2023-11-25 09:03:46
# 1  PlayStation Plus Premium members can spend two...  2023-11-24 18:34:27
# 2  Share of the Week dives into the rogues galler...  2023-11-24 17:01:25
# 3  Time to talk turkey.\n\nDig in to Black Friday...  2023-11-24 15:59:28
# 4                   Which PlayStation Shape are you?  2023-11-23 09:10:01
#
#                                    images_lowquality  \
# 0  ['https://scontent-sin6-2.xx.fbcdn.net/v/t39.3...
# 1  ['https://scontent-sin6-2.xx.fbcdn.net/v/t39.3...
# 2  ['https://scontent-sin6-2.xx.fbcdn.net/v/t39.3...
# 3  ['https://scontent-sin6-1.xx.fbcdn.net/v/t39.3...
# 4  ['https://scontent-sin6-2.xx.fbcdn.net/v/t15.5...
#
#                                                video         video_id  \
# 0                                                NaN              NaN
# 1                                                NaN              NaN
# 2                                                NaN              NaN
# 3                                                NaN              NaN
# 4  https://scontent-sin6-4.xx.fbcdn.net/v/t42.179...  355486430302074
#
#                                      video_thumbnail likes comments shares  \
# 0                                                NaN   331       27      5
# 1                                                NaN  1672      645    100
# 2                                                NaN  1301       55    140
# 3                                                NaN   577      152     21
# 4  https://scontent-sin6-2.xx.fbcdn.net/v/t15.525...   232       46     27
#
#                                                 link  \
# 0                                                NaN
# 1  http://play.st/46vrSBk?fbclid=IwAR3GOZbEQUh3Cm...
# 2  http://play.st/3MWJW0b?fbclid=IwAR3RXfHAOiHHj0...
# 3  https://play.st/49PebQt?fbclid=IwAR2FKWq8ipoNM...
# 4  https://play.st/49FJWvj?fbclid=IwAR0LHhqDX-250...
#
#                                                links  \
# 0  [{'link': '/story.php?story_fbid=8697658714805...
# 1  [{'link': 'https://lm.facebook.com/l.php?u=htt...
# 2  [{'link': '/hashtag/spiderman2ps5?refid=17&_ft...
# 3  [{'link': 'https://lm.facebook.com/l.php?u=htt...
# 4  [{'link': '/story.php?story_fbid=pfbid02u9iyTX...
#
#                                        comments_full  \
# 0  <generator object PostExtractor.extract_commen...
# 1  <generator object PostExtractor.extract_commen...
# 2  <generator object PostExtractor.extract_commen...
# 3  <generator object PostExtractor.extract_commen...
# 4  <generator object PostExtractor.extract_commen...
#
#                                             reactors  \
# 0  <generator object PostExtractor.extract_reacto...
# 1  <generator object PostExtractor.extract_reacto...
# 2  <generator object PostExtractor.extract_reacto...
# 3  <generator object PostExtractor.extract_reacto...
# 4  <generator object PostExtractor.extract_reacto...
#
#                                            reactions reaction_count  \
# 0  {'like': 331, 'love': 80, 'haha': 8, 'wow': 1,...            426
# 1  {'like': 1672, 'love': 286, 'haha': 184, 'wow'...           2198
# 2  {'like': 1301, 'love': 502, 'haha': 7, 'wow': ...           1831
# 3  {'like': 577, 'love': 50, 'haha': 89, 'wow': 1...            724
# 4  {'like': 232, 'love': 43, 'haha': 8, 'wow': 6,...            293
#
#        page_id                                            sharers has_vid
# 0  14104316802  <generator object PostExtractor.extract_sharer...   False
# 1  14104316802  <generator object PostExtractor.extract_sharer...   False
# 2  14104316802  <generator object PostExtractor.extract_sharer...   False
# 3  14104316802  <generator object PostExtractor.extract_sharer...   False
# 4  14104316802  <generator object PostExtractor.extract_sharer...    True

# %%
data = data.drop(columns=["video", "video_id", "video_thumbnail"])

data.head()
# Out:
#            post_id                                               text  \
# 0  730016209160819                                                NaN
# 1  729723005856806  PlayStation Plus Premium members can spend two...
# 2  728763929286047  Share of the Week dives into the rogues galler...
# 3  729647439197696  Time to talk turkey.\n\nDig in to Black Friday...
# 4  728960592599714  Which PlayStation Shape are you?\n\nプレイステーション ...
#
#                                            post_text                 time  \
# 0                                                NaN  2023-11-25 09:03:46
# 1  PlayStation Plus Premium members can spend two...  2023-11-24 18:34:27
# 2  Share of the Week dives into the rogues galler...  2023-11-24 17:01:25
# 3  Time to talk turkey.\n\nDig in to Black Friday...  2023-11-24 15:59:28
# 4                   Which PlayStation Shape are you?  2023-11-23 09:10:01
#
#                                    images_lowquality likes comments shares  \
# 0  ['https://scontent-sin6-2.xx.fbcdn.net/v/t39.3...   331       27      5
# 1  ['https://scontent-sin6-2.xx.fbcdn.net/v/t39.3...  1672      645    100
# 2  ['https://scontent-sin6-2.xx.fbcdn.net/v/t39.3...  1301       55    140
# 3  ['https://scontent-sin6-1.xx.fbcdn.net/v/t39.3...   577      152     21
# 4  ['https://scontent-sin6-2.xx.fbcdn.net/v/t15.5...   232       46     27
#
#                                                 link  \
# 0                                                NaN
# 1  http://play.st/46vrSBk?fbclid=IwAR3GOZbEQUh3Cm...
# 2  http://play.st/3MWJW0b?fbclid=IwAR3RXfHAOiHHj0...
# 3  https://play.st/49PebQt?fbclid=IwAR2FKWq8ipoNM...
# 4  https://play.st/49FJWvj?fbclid=IwAR0LHhqDX-250...
#
#                                                links  \
# 0  [{'link': '/story.php?story_fbid=8697658714805...
# 1  [{'link': 'https://lm.facebook.com/l.php?u=htt...
# 2  [{'link': '/hashtag/spiderman2ps5?refid=17&_ft...
# 3  [{'link': 'https://lm.facebook.com/l.php?u=htt...
# 4  [{'link': '/story.php?story_fbid=pfbid02u9iyTX...
#
#                                        comments_full  \
# 0  <generator object PostExtractor.extract_commen...
# 1  <generator object PostExtractor.extract_commen...
# 2  <generator object PostExtractor.extract_commen...
# 3  <generator object PostExtractor.extract_commen...
# 4  <generator object PostExtractor.extract_commen...
#
#                                             reactors  \
# 0  <generator object PostExtractor.extract_reacto...
# 1  <generator object PostExtractor.extract_reacto...
# 2  <generator object PostExtractor.extract_reacto...
# 3  <generator object PostExtractor.extract_reacto...
# 4  <generator object PostExtractor.extract_reacto...
#
#                                            reactions reaction_count  \
# 0  {'like': 331, 'love': 80, 'haha': 8, 'wow': 1,...            426
# 1  {'like': 1672, 'love': 286, 'haha': 184, 'wow'...           2198
# 2  {'like': 1301, 'love': 502, 'haha': 7, 'wow': ...           1831
# 3  {'like': 577, 'love': 50, 'haha': 89, 'wow': 1...            724
# 4  {'like': 232, 'love': 43, 'haha': 8, 'wow': 6,...            293
#
#        page_id                                            sharers has_vid
# 0  14104316802  <generator object PostExtractor.extract_sharer...   False
# 1  14104316802  <generator object PostExtractor.extract_sharer...   False
# 2  14104316802  <generator object PostExtractor.extract_sharer...   False
# 3  14104316802  <generator object PostExtractor.extract_sharer...   False
# 4  14104316802  <generator object PostExtractor.extract_sharer...    True

# %% [markdown]
# ### Create column "has_image"

# %%
has_imp = []
for image in data["images_lowquality"]:
    if image is not np.nan:
        has_imp.append(True)
    else:
        has_imp.append(False)
data["has_image"] = pd.DataFrame(has_imp)
data.head()
# Out:
#            post_id                                               text  \
# 0  730016209160819                                                NaN
# 1  729723005856806  PlayStation Plus Premium members can spend two...
# 2  728763929286047  Share of the Week dives into the rogues galler...
# 3  729647439197696  Time to talk turkey.\n\nDig in to Black Friday...
# 4  728960592599714  Which PlayStation Shape are you?\n\nプレイステーション ...
#
#                                            post_text                 time  \
# 0                                                NaN  2023-11-25 09:03:46
# 1  PlayStation Plus Premium members can spend two...  2023-11-24 18:34:27
# 2  Share of the Week dives into the rogues galler...  2023-11-24 17:01:25
# 3  Time to talk turkey.\n\nDig in to Black Friday...  2023-11-24 15:59:28
# 4                   Which PlayStation Shape are you?  2023-11-23 09:10:01
#
#                                    images_lowquality likes comments shares  \
# 0  ['https://scontent-sin6-2.xx.fbcdn.net/v/t39.3...   331       27      5
# 1  ['https://scontent-sin6-2.xx.fbcdn.net/v/t39.3...  1672      645    100
# 2  ['https://scontent-sin6-2.xx.fbcdn.net/v/t39.3...  1301       55    140
# 3  ['https://scontent-sin6-1.xx.fbcdn.net/v/t39.3...   577      152     21
# 4  ['https://scontent-sin6-2.xx.fbcdn.net/v/t15.5...   232       46     27
#
#                                                 link  \
# 0                                                NaN
# 1  http://play.st/46vrSBk?fbclid=IwAR3GOZbEQUh3Cm...
# 2  http://play.st/3MWJW0b?fbclid=IwAR3RXfHAOiHHj0...
# 3  https://play.st/49PebQt?fbclid=IwAR2FKWq8ipoNM...
# 4  https://play.st/49FJWvj?fbclid=IwAR0LHhqDX-250...
#
#                                                links  \
# 0  [{'link': '/story.php?story_fbid=8697658714805...
# 1  [{'link': 'https://lm.facebook.com/l.php?u=htt...
# 2  [{'link': '/hashtag/spiderman2ps5?refid=17&_ft...
# 3  [{'link': 'https://lm.facebook.com/l.php?u=htt...
# 4  [{'link': '/story.php?story_fbid=pfbid02u9iyTX...
#
#                                        comments_full  \
# 0  <generator object PostExtractor.extract_commen...
# 1  <generator object PostExtractor.extract_commen...
# 2  <generator object PostExtractor.extract_commen...
# 3  <generator object PostExtractor.extract_commen...
# 4  <generator object PostExtractor.extract_commen...
#
#                                             reactors  \
# 0  <generator object PostExtractor.extract_reacto...
# 1  <generator object PostExtractor.extract_reacto...
# 2  <generator object PostExtractor.extract_reacto...
# 3  <generator object PostExtractor.extract_reacto...
# 4  <generator object PostExtractor.extract_reacto...
#
#                                            reactions reaction_count  \
# 0  {'like': 331, 'love': 80, 'haha': 8, 'wow': 1,...            426
# 1  {'like': 1672, 'love': 286, 'haha': 184, 'wow'...           2198
# 2  {'like': 1301, 'love': 502, 'haha': 7, 'wow': ...           1831
# 3  {'like': 577, 'love': 50, 'haha': 89, 'wow': 1...            724
# 4  {'like': 232, 'love': 43, 'haha': 8, 'wow': 6,...            293
#
#        page_id                                            sharers has_vid  \
# 0  14104316802  <generator object PostExtractor.extract_sharer...   False
# 1  14104316802  <generator object PostExtractor.extract_sharer...   False
# 2  14104316802  <generator object PostExtractor.extract_sharer...   False
# 3  14104316802  <generator object PostExtractor.extract_sharer...   False
# 4  14104316802  <generator object PostExtractor.extract_sharer...    True
#
#   has_image
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True

# %%
data = data.drop(columns="images_lowquality")
data.reset_index()
# Out:
#      index            post_id  \
# 0        0    730016209160819
# 1        1    729723005856806
# 2        2    728763929286047
# 3        3    729647439197696
# 4        4    728960592599714
# ..     ...                ...
# 605    666  10161430145771803
# 606    667  10161429315211803
# 607    668  10161429575366803
# 608    669  10161429455771803
# 609    670    257258567130564
#
#                                                   text  \
# 0                                                  NaN
# 1    PlayStation Plus Premium members can spend two...
# 2    Share of the Week dives into the rogues galler...
# 3    Time to talk turkey.\n\nDig in to Black Friday...
# 4    Which PlayStation Shape are you?\n\nプレイステーション ...
# ..                                                 ...
# 605  Round 1 - Fight!\n\nA Street Fighter 6 demo la...
# 606  Unleash your inner beast as the Druid in Diabl...
# 607  Great news: Firewalk Studios is joining the Pl...
# 608  Turn the tides in Crash Team Rumble with power...
# 609  The EU Tekken 7 Fight Nights Invitational is l...
#
#                                              post_text                 time  \
# 0                                                  NaN  2023-11-25 09:03:46
# 1    PlayStation Plus Premium members can spend two...  2023-11-24 18:34:27
# 2    Share of the Week dives into the rogues galler...  2023-11-24 17:01:25
# 3    Time to talk turkey.\n\nDig in to Black Friday...  2023-11-24 15:59:28
# 4                     Which PlayStation Shape are you?  2023-11-23 09:10:01
# ..                                                 ...                  ...
# 605  Round 1 - Fight!\n\nA Street Fighter 6 demo la...  2023-04-20 22:40:15
# 606  Unleash your inner beast as the Druid in Diabl...  2023-04-20 17:35:00
# 607  Great news: Firewalk Studios is joining the Pl...  2023-04-20 17:12:52
# 608  Turn the tides in Crash Team Rumble with power...  2023-04-20 16:00:56
# 609  The EU Tekken 7 Fight Nights Invitational is l...  2023-04-20 15:46:42
#
#      likes comments shares                                               link  \
# 0      331       27      5                                                NaN
# 1     1672      645    100  http://play.st/46vrSBk?fbclid=IwAR3GOZbEQUh3Cm...
# 2     1301       55    140  http://play.st/3MWJW0b?fbclid=IwAR3RXfHAOiHHj0...
# 3      577      152     21  https://play.st/49PebQt?fbclid=IwAR2FKWq8ipoNM...
# 4      232       46     27  https://play.st/49FJWvj?fbclid=IwAR0LHhqDX-250...
# ..     ...      ...    ...                                                ...
# 605    829      117    174  http://play.st/3An9a0Z?fbclid=IwAR2cre9W6e6im_...
# 606    755      169     58                                                NaN
# 607   3047      741    210  https://blog.playstation.com/2023/04/20/welcom...
# 608  16039      183    529  http://play.st/41EvEpS?fbclid=IwAR0hGAELA8swvZ...
# 609    199       32     13  https://playst.cc/3EvOUOl?fbclid=IwAR0sOohUJ7R...
#
#                                                  links  \
# 0    [{'link': '/story.php?story_fbid=8697658714805...
# 1    [{'link': 'https://lm.facebook.com/l.php?u=htt...
# 2    [{'link': '/hashtag/spiderman2ps5?refid=17&_ft...
# 3    [{'link': 'https://lm.facebook.com/l.php?u=htt...
# 4    [{'link': '/story.php?story_fbid=pfbid02u9iyTX...
# ..                                                 ...
# 605  [{'link': 'https://lm.facebook.com/l.php?u=htt...
# 606  [{'link': '/story.php?story_fbid=pfbid0pew7xwo...
# 607  [{'link': '/story.php?story_fbid=pfbid02fU6bE9...
# 608  [{'link': 'https://lm.facebook.com/l.php?u=htt...
# 609  [{'link': 'https://lm.facebook.com/l.php?u=htt...
#
#                                          comments_full  \
# 0    <generator object PostExtractor.extract_commen...
# 1    <generator object PostExtractor.extract_commen...
# 2    <generator object PostExtractor.extract_commen...
# 3    <generator object PostExtractor.extract_commen...
# 4    <generator object PostExtractor.extract_commen...
# ..                                                 ...
# 605  <generator object PostExtractor.extract_commen...
# 606  <generator object PostExtractor.extract_commen...
# 607  <generator object PostExtractor.extract_commen...
# 608  <generator object PostExtractor.extract_commen...
# 609  <generator object PostExtractor.extract_commen...
#
#                                               reactors  \
# 0    <generator object PostExtractor.extract_reacto...
# 1    <generator object PostExtractor.extract_reacto...
# 2    <generator object PostExtractor.extract_reacto...
# 3    <generator object PostExtractor.extract_reacto...
# 4    <generator object PostExtractor.extract_reacto...
# ..                                                 ...
# 605  <generator object PostExtractor.extract_reacto...
# 606  <generator object PostExtractor.extract_reacto...
# 607  <generator object PostExtractor.extract_reacto...
# 608  <generator object PostExtractor.extract_reacto...
# 609  <generator object PostExtractor.extract_reacto...
#
#                                              reactions reaction_count  \
# 0    {'like': 331, 'love': 80, 'haha': 8, 'wow': 1,...            426
# 1    {'like': 1672, 'love': 286, 'haha': 184, 'wow'...           2198
# 2    {'like': 1301, 'love': 502, 'haha': 7, 'wow': ...           1831
# 3    {'like': 577, 'love': 50, 'haha': 89, 'wow': 1...            724
# 4    {'like': 232, 'love': 43, 'haha': 8, 'wow': 6,...            293
# ..                                                 ...            ...
# 605  {'like': 829, 'love': 155, 'haha': 8, 'wow': 8...           1008
# 606  {'like': 755, 'love': 120, 'haha': 5, 'wow': 8...            897
# 607  {'like': 3047, 'love': 554, 'haha': 77, 'wow':...           3728
# 608  {'like': 16039, 'love': 8209, 'haha': 26, 'wow...          40275
# 609  {'like': 199, 'love': 33, 'haha': 2, 'wow': 4,...            243
#
#          page_id                                            sharers has_vid  \
# 0    14104316802  <generator object PostExtractor.extract_sharer...   False
# 1    14104316802  <generator object PostExtractor.extract_sharer...   False
# 2    14104316802  <generator object PostExtractor.extract_sharer...   False
# 3    14104316802  <generator object PostExtractor.extract_sharer...   False
# 4    14104316802  <generator object PostExtractor.extract_sharer...    True
# ..           ...                                                ...     ...
# 605  14104316802  <generator object PostExtractor.extract_sharer...     NaN
# 606  14104316802  <generator object PostExtractor.extract_sharer...     NaN
# 607  14104316802  <generator object PostExtractor.extract_sharer...     NaN
# 608  14104316802  <generator object PostExtractor.extract_sharer...     NaN
# 609  14104316802  <generator object PostExtractor.extract_sharer...     NaN
#
#     has_image
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
# ..        ...
# 605       NaN
# 606       NaN
# 607       NaN
# 608       NaN
# 609       NaN
#
# [610 rows x 18 columns]

# %%
data.head()
# Out:
#            post_id                                               text  \
# 0  730016209160819                                                NaN
# 1  729723005856806  PlayStation Plus Premium members can spend two...
# 2  728763929286047  Share of the Week dives into the rogues galler...
# 3  729647439197696  Time to talk turkey.\n\nDig in to Black Friday...
# 4  728960592599714  Which PlayStation Shape are you?\n\nプレイステーション ...
#
#                                            post_text                 time  \
# 0                                                NaN  2023-11-25 09:03:46
# 1  PlayStation Plus Premium members can spend two...  2023-11-24 18:34:27
# 2  Share of the Week dives into the rogues galler...  2023-11-24 17:01:25
# 3  Time to talk turkey.\n\nDig in to Black Friday...  2023-11-24 15:59:28
# 4                   Which PlayStation Shape are you?  2023-11-23 09:10:01
#
#   likes comments shares                                               link  \
# 0   331       27      5                                                NaN
# 1  1672      645    100  http://play.st/46vrSBk?fbclid=IwAR3GOZbEQUh3Cm...
# 2  1301       55    140  http://play.st/3MWJW0b?fbclid=IwAR3RXfHAOiHHj0...
# 3   577      152     21  https://play.st/49PebQt?fbclid=IwAR2FKWq8ipoNM...
# 4   232       46     27  https://play.st/49FJWvj?fbclid=IwAR0LHhqDX-250...
#
#                                                links  \
# 0  [{'link': '/story.php?story_fbid=8697658714805...
# 1  [{'link': 'https://lm.facebook.com/l.php?u=htt...
# 2  [{'link': '/hashtag/spiderman2ps5?refid=17&_ft...
# 3  [{'link': 'https://lm.facebook.com/l.php?u=htt...
# 4  [{'link': '/story.php?story_fbid=pfbid02u9iyTX...
#
#                                        comments_full  \
# 0  <generator object PostExtractor.extract_commen...
# 1  <generator object PostExtractor.extract_commen...
# 2  <generator object PostExtractor.extract_commen...
# 3  <generator object PostExtractor.extract_commen...
# 4  <generator object PostExtractor.extract_commen...
#
#                                             reactors  \
# 0  <generator object PostExtractor.extract_reacto...
# 1  <generator object PostExtractor.extract_reacto...
# 2  <generator object PostExtractor.extract_reacto...
# 3  <generator object PostExtractor.extract_reacto...
# 4  <generator object PostExtractor.extract_reacto...
#
#                                            reactions reaction_count  \
# 0  {'like': 331, 'love': 80, 'haha': 8, 'wow': 1,...            426
# 1  {'like': 1672, 'love': 286, 'haha': 184, 'wow'...           2198
# 2  {'like': 1301, 'love': 502, 'haha': 7, 'wow': ...           1831
# 3  {'like': 577, 'love': 50, 'haha': 89, 'wow': 1...            724
# 4  {'like': 232, 'love': 43, 'haha': 8, 'wow': 6,...            293
#
#        page_id                                            sharers has_vid  \
# 0  14104316802  <generator object PostExtractor.extract_sharer...   False
# 1  14104316802  <generator object PostExtractor.extract_sharer...   False
# 2  14104316802  <generator object PostExtractor.extract_sharer...   False
# 3  14104316802  <generator object PostExtractor.extract_sharer...   False
# 4  14104316802  <generator object PostExtractor.extract_sharer...    True
#
#   has_image
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True

# %% [markdown]
# ### Make a columns name "post_time" to show the frequency of time page post a post

# %%
convert_to_time = []
for time in data["time"]:
    try:
        convert_to_time.append(datetime.strptime(time, '%Y-%m-%d %H:%M:%S'))
    except:
        convert_to_time.append(np.nan)
len(convert_to_time)

data["post_time"] = pd.DataFrame(convert_to_time)
data["post_time"] = pd.to_datetime(data["post_time"]).dt.time

# %%
data = data.dropna(axis=0, subset=["post_time"])

# %% [markdown]
# ## Make type of reaction columns

# %%
reaction = data["reactions"].apply(ast.literal_eval).apply(pd.Series)
reaction
# Out:
#        like   love   haha   wow  care  sad  angry
# 0     331.0   80.0    8.0   1.0   3.0  1.0    2.0
# 1    1672.0  286.0  184.0  36.0  11.0  2.0    7.0
# 2    1301.0  502.0    7.0   6.0  14.0  NaN    1.0
# 3     577.0   50.0   89.0   1.0   3.0  NaN    4.0
# 4     232.0   43.0    8.0   6.0   3.0  NaN    1.0
# ..      ...    ...    ...   ...   ...  ...    ...
# 596   841.0  108.0   14.0   6.0   5.0  NaN    3.0
# 597   946.0  167.0    8.0   3.0  10.0  NaN    1.0
# 598  1403.0  290.0  101.0  14.0  18.0  1.0    NaN
# 599  1208.0  230.0   14.0  13.0   9.0  NaN    1.0
# 600   552.0   88.0    3.0   8.0   3.0  NaN    NaN
#
# [549 rows x 7 columns]

# %% [markdown]
# ### Convert NaN value into 0 and float into integer

# %%
reaction = reaction.fillna(0).astype(int)
reaction
# Out:
#      like  love  haha  wow  care  sad  angry
# 0     331    80     8    1     3    1      2
# 1    1672   286   184   36    11    2      7
# 2    1301   502     7    6    14    0      1
# 3     577    50    89    1     3    0      4
# 4     232    43     8    6     3    0      1
# ..    ...   ...   ...  ...   ...  ...    ...
# 596   841   108    14    6     5    0      3
# 597   946   167     8    3    10    0      1
# 598  1403   290   101   14    18    1      0
# 599  1208   230    14   13     9    0      1
# 600   552    88     3    8     3    0      0
#
# [549 rows x 7 columns]

# %% [markdown]
# ### Add reaction Dataframe into data

# %%
data = pd.concat([data, reaction], axis=1)
data
# Out:
#                post_id                                               text  \
# 0      730016209160819                                                NaN
# 1      729723005856806  PlayStation Plus Premium members can spend two...
# 2      728763929286047  Share of the Week dives into the rogues galler...
# 3      729647439197696  Time to talk turkey.\n\nDig in to Black Friday...
# 4      728960592599714  Which PlayStation Shape are you?\n\nプレイステーション ...
# ..                 ...                                                ...
# 596  10161442502256803  Perfect lightsaber parries to repel blaster fi...
# 597  10161446959161803                          Zipping into the weekend.
# 598  10161447467776803  We’re seeing the effects of The Last on Us Par...
# 599  10161446954061803  The galaxy is now more dangerous than ever, bu...
# 600  10161447262151803  Share of the Week highlights Ghostwire: Tokyo:...
#
#                                              post_text                 time  \
# 0                                                  NaN  2023-11-25 09:03:46
# 1    PlayStation Plus Premium members can spend two...  2023-11-24 18:34:27
# 2    Share of the Week dives into the rogues galler...  2023-11-24 17:01:25
# 3    Time to talk turkey.\n\nDig in to Black Friday...  2023-11-24 15:59:28
# 4                     Which PlayStation Shape are you?  2023-11-23 09:10:01
# ..                                                 ...                  ...
# 596  Perfect lightsaber parries to repel blaster fi...  2023-04-29 15:00:02
# 597                          Zipping into the weekend.  2023-04-28 22:00:02
# 598  We’re seeing the effects of The Last on Us Par...  2023-04-28 17:01:35
# 599  The galaxy is now more dangerous than ever, bu...  2023-04-28 16:15:01
# 600  Share of the Week highlights Ghostwire: Tokyo:...  2023-04-28 16:02:18
#
#     likes comments shares                                               link  \
# 0     331       27      5                                                NaN
# 1    1672      645    100  http://play.st/46vrSBk?fbclid=IwAR3GOZbEQUh3Cm...
# 2    1301       55    140  http://play.st/3MWJW0b?fbclid=IwAR3RXfHAOiHHj0...
# 3     577      152     21  https://play.st/49PebQt?fbclid=IwAR2FKWq8ipoNM...
# 4     232       46     27  https://play.st/49FJWvj?fbclid=IwAR0LHhqDX-250...
# ..    ...      ...    ...                                                ...
# 596   841      270     33  http://play.st/41FBWGm?fbclid=IwAR3fvZ5FL2LVJK...
# 597   946      149     34                                                NaN
# 598  1403      106    106                                                NaN
# 599  1208      245     50  http://play.st/41Pm5oI?fbclid=IwAR1AOiAmMN4X8S...
# 600   552       23     58  http://play.st/3n75i1t?fbclid=IwAR0HxJfORBQxHR...
#
#                                                  links  \
# 0    [{'link': '/story.php?story_fbid=8697658714805...
# 1    [{'link': 'https://lm.facebook.com/l.php?u=htt...
# 2    [{'link': '/hashtag/spiderman2ps5?refid=17&_ft...
# 3    [{'link': 'https://lm.facebook.com/l.php?u=htt...
# 4    [{'link': '/story.php?story_fbid=pfbid02u9iyTX...
# ..                                                 ...
# 596  [{'link': 'https://lm.facebook.com/l.php?u=htt...
# 597  [{'link': '/story.php?story_fbid=pfbid066TTZaF...
# 598  [{'link': '/hashtag/livefromps5?_ft_=encrypted...
# 599  [{'link': 'https://lm.facebook.com/l.php?u=htt...
# 600  [{'link': 'https://lm.facebook.com/l.php?u=htt...
#
#                                          comments_full  ... post_time  like  \
# 0    <generator object PostExtractor.extract_commen...  ...  09:03:46   331
# 1    <generator object PostExtractor.extract_commen...  ...  18:34:27  1672
# 2    <generator object PostExtractor.extract_commen...  ...  17:01:25  1301
# 3    <generator object PostExtractor.extract_commen...  ...  15:59:28   577
# 4    <generator object PostExtractor.extract_commen...  ...  09:10:01   232
# ..                                                 ...  ...       ...   ...
# 596  <generator object PostExtractor.extract_commen...  ...  14:15:01   841
# 597  <generator object PostExtractor.extract_commen...  ...  01:30:00   946
# 598  <generator object PostExtractor.extract_commen...  ...  00:52:30  1403
# 599  <generator object PostExtractor.extract_commen...  ...  20:45:03  1208
# 600  <generator object PostExtractor.extract_commen...  ...  19:00:00   552
#
#                                               reaction  like love haha wow  \
# 0    {'like': 331, 'love': 80, 'haha': 8, 'wow': 1,...   331   80    8   1
# 1    {'like': 1672, 'love': 286, 'haha': 184, 'wow'...  1672  286  184  36
# 2    {'like': 1301, 'love': 502, 'haha': 7, 'wow': ...  1301  502    7   6
# 3    {'like': 577, 'love': 50, 'haha': 89, 'wow': 1...   577   50   89   1
# 4    {'like': 232, 'love': 43, 'haha': 8, 'wow': 6,...   232   43    8   6
# ..                                                 ...   ...  ...  ...  ..
# 596  {'like': 841, 'love': 108, 'haha': 14, 'wow': ...   841  108   14   6
# 597  {'like': 946, 'love': 167, 'haha': 8, 'wow': 3...   946  167    8   3
# 598  {'like': 1403, 'love': 290, 'haha': 101, 'wow'...  1403  290  101  14
# 599  {'like': 1208, 'love': 230, 'haha': 14, 'wow':...  1208  230   14  13
# 600  {'like': 552, 'love': 88, 'haha': 3, 'wow': 8,...   552   88    3   8
#
#     care sad angry
# 0      3   1     2
# 1     11   2     7
# 2     14   0     1
# 3      3   0     4
# 4      3   0     1
# ..   ...  ..   ...
# 596    5   0     3
# 597   10   0     1
# 598   18   1     0
# 599    9   0     1
# 600    3   0     0
#
# [549 rows x 27 columns]

# %% [markdown]
# ## Save clean file

# %%
data.to_csv(f"{os.getenv('FOLDER_PATH_CLEAN')}{os.getenv('FACEBOOK_FANPAGE_ID')}.csv", mode="w", index=False)
